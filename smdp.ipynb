# %%
import gymnasium as gym
from matplotlib import pyplot as plt
import re
import numpy as np
from tqdm.notebook import trange, tqdm
from math import floor

# %%
def row_col_to_seq(row_col, num_cols):
    '''
    Converts row_col to num_cols format

    Args:
        row_col (np.ndarray): Location of shape (1,2)
        num_cols (int): Total number of cols
    Return:
        (np.ndarray): Number format of row and column of shape (1,)
  '''
    return row_col[:,0] * num_cols + row_col[:,1]

def seq_to_col_row(seq, num_cols):
    '''
    Converts state number to rol_col format
    Args:
        seq (int): Number format of state
        num_cols (int): Number of columns
    Return:
        (np.ndarray): Array of shape (1,2) as [[row, col]]
    '''
    r = floor(seq / num_cols)
    c = seq - r * num_cols
    return np.array([[r, c]])

# %%
def policy_ep(q_values, state, ep):
    num_actions = q_values.shape[1]
    rand_num = np.random.random()
    if rand_num < ep:
        action = np.random.choice(np.arange(num_actions))
    else:
        action = np.argmax(q_values[state,:])

    return action

# %%
env = gym.make('Taxi-v3', render_mode = 'ansi')
s = env.reset()
print(env.render())
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
# def run_option(state, option, ep, q_vals):
#     opt_terminal_states = {0:[0,0], 1:[0,4], 2:[4,0],3:[4,3]}
#     # Decoding state for row, col, pass_loc, dest_loc
#     taxi_row, taxi_col, pass_loc, dest_loc = env.decode(state)
#     # Getting row and col for option terminal loc
#     taxi_target_row, taxi_target_col = opt_terminal_states[option]

#     # Checking if target loc is reached or not
#     if taxi_row == taxi_target_row and taxi_col == taxi_target_col:
#         print(f'Taxi checks: state = {taxi_row}, {taxi_col}, target = {taxi_target_row},{taxi_target_col}')

#         # Goal point reached
#         optdone = True
#         # check passeger loc
#         if option == pass_loc:
#             action = 4
#         elif option == dest_loc:
#             action = 5
#         else:
#             action = 1 if (option in [0,1]) else 0
#     else:
#         optdone = False
#         # Choosing action
#         action = policy_ep(q_vals[:,:,option], state, ep)

#     return action,optdone

# %%
def run_option(state, option, ep, q_vals):
    opt_terminal_states = {0:[0,0], 1:[0,4], 2:[4,0],3:[4,3]}
    # Decoding state for row, col, pass_loc, dest_loc
    taxi_row, taxi_col, pass_loc, dest_loc = env.decode(state)
    state_act_seq = row_col_to_seq(np.array([[taxi_row,taxi_col]]), 5)
    # Getting row and col for option terminal loc
    taxi_target_row, taxi_target_col = opt_terminal_states[option]

    # Checking if target loc is reached or not
    if taxi_row == taxi_target_row and taxi_col == taxi_target_col:
        #print(f'Taxi checks: state = {taxi_row}, {taxi_col}, target = {taxi_target_row},{taxi_target_col}')

        # Goal point reached
        optdone = True
        # check passeger loc
        if option == pass_loc:
            action = 4
        elif option == dest_loc:
            action = 5
        else:
            action = 1 if (option in [0,1]) else 0
    else:
        optdone = False
        # Choosing action
        action = policy_ep(q_vals[:,:,option], state_act_seq, ep)

    return action,optdone

# %%
row = 5
col = 5
num_pass_loc = 5
num_dest_loc = 4
num_options = 4 # Goto R, G, Y, B
num_primitive_act = 6
num_states = 500
tot_actions = num_primitive_act + num_options

# %%
gamma = 0.99
alpha = 0.5
ep = 0.01
# ep_max = 0.5
# ep_min = 0.01
# decay = 0.99
#ep_opt = np.ones(4)*ep_max

num_episodes = 1000
opt_terminal_states = {0:[0,0], 1:[0,4], 2:[4,0],3:[4,3]}
q_val_opt = np.zeros((num_pass_loc*num_dest_loc, num_options)) # shape= (20,4)
q_val_actions = np.zeros((row*col, num_primitive_act, num_options)) # shape (25,6,4)


for i in tqdm(range(num_episodes)):
    curr_state = env.reset()[0]
    #taxi_start_row, taxi_start_col, pass_loc, dest_idx = env.decode(curr_state)
    done = False
    steps = 0
    tot_reward = 0

    while not done:
        # Decoding state
        taxi_row, taxi_col, pass_loc, dest_idx = env.decode(curr_state)
        curr_opt_seq = row_col_to_seq(np.array([[pass_loc, dest_idx]]), num_dest_loc)

        # choose option
        option = policy_ep(q_val_opt, curr_opt_seq, ep)

        optdone = False
        reward_bar = 0
        opt_start_state = curr_opt_seq
        k = 0

        while not optdone:
            opt_action,optdone = run_option(state = curr_state,
                                            option = option,
                                            ep = ep,
                                            q_vals = q_val_actions)
            next_state, reward, is_terminal, truncated, t_prob = env.step(opt_action)
            reward_bar = gamma*reward_bar + reward
            tot_reward = tot_reward + reward

            # decode curr, next state
            taxi_curr_row, taxi_curr_col, pass_curr_loc, dest_curr_idx = env.decode(curr_state)
            taxi_next_row, taxi_next_col, pass_next_loc, dest_next_idx = env.decode(next_state)
            curr_act_seq = row_col_to_seq(np.array([[taxi_curr_row,taxi_curr_col]]), 5)
            next_act_seq = row_col_to_seq(np.array([[taxi_next_row,taxi_next_col]]), 5)

            q_val_actions[curr_act_seq,opt_action,option] = q_val_actions[curr_act_seq,opt_action,option] + alpha * (reward + gamma * np.max(q_val_actions[next_act_seq,:,option]) - q_val_actions[curr_act_seq,opt_action,option])

            if is_terminal:
                done = True
            if optdone:
                opt_terminal_state = next_state
            k += 1
            steps += 1
            curr_state = next_state
            #ep_opt[option] = ep_min #max(ep_min,decay*ep_opt[option])

        #decode and encode option start and end
        opt_start_row, opt_start_col, pass_start_loc, dest_start_idx = env.decode(opt_start_state)
        opt_end_row, opt_end_col, pass_end_loc, dest_end_idx = env.decode(opt_terminal_state)
        curr_opt_seq = row_col_to_seq(np.array([[pass_start_loc,dest_start_idx]]), 4)
        end_opt_seq = row_col_to_seq(np.array([[pass_end_loc,dest_end_idx]]), 4)
        q_val_opt[curr_opt_seq, option] = q_val_opt[curr_opt_seq, option] + alpha * (reward_bar + (gamma**k)*np.max(q_val_opt[end_opt_seq]) - q_val_opt[curr_opt_seq, option])

    print(f'ep = {i}, steps = {steps}, total reward = {tot_reward},')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ep = 0, steps = 1998, total reward = -3777,
# ep = 1, steps = 333, total reward = -321,
# ep = 2, steps = 80, total reward = -77,
# ep = 3, steps = 363, total reward = -360,
# ep = 4, steps = 205, total reward = -202,
# ep = 5, steps = 190, total reward = -196,
# ep = 6, steps = 364, total reward = -406,
# ep = 7, steps = 36, total reward = -15,
# ep = 8, steps = 19, total reward = 2,
# ep = 9, steps = 93, total reward = -99,
# ep = 10, steps = 283, total reward = -442,
# ep = 11, steps = 46, total reward = -34,
# ep = 12, steps = 75, total reward = -63,
# ep = 13, steps = 16, total reward = 5,
# ep = 14, steps = 324, total reward = -393,
# ep = 15, steps = 49, total reward = -46,
# ep = 16, steps = 83, total reward = -107,
# ep = 17, steps = 38, total reward = -26,
# ep = 18, steps = 20, total reward = 1,
# ep = 19, steps = 44, total reward = -32,
# ep = 20, steps = 23, total reward = -2,
# ep = 21, steps = 15, total reward = 6,
# ep = 22, steps = 7, total reward = 14,
# ep = 23, steps = 10, total reward = 11,
# ep = 24, steps = 7, total reward = 14,
# ep = 25, steps = 74, total reward = -62,
# ep = 26, steps = 12, total reward = 9,
# ep = 27, steps = 32, total reward = -11,
# ep = 28, steps = 15, total reward = 6,
# ep = 29, steps = 146, total reward = -152,
# ep = 30, steps = 25, total reward = -4,
# ep = 31, steps = 11, total reward = 10,
# ep = 32, steps = 50, total reward = -47,
# ep = 33, steps = 28, total reward = -7,
# ep = 34, steps = 15, total reward = 6,
# ep = 35, steps = 44, total reward = -32,
# ep = 36, steps = 19, total reward = 2,
# ep = 37, steps = 14, total reward = 7,
# ep = 38, steps = 12, total reward = 9,
# ep = 39, steps = 13, total reward = 8,
# ep = 40, steps = 16, total reward = 5,
# ep = 41, steps = 45, total reward = -42,
# ep = 42, steps = 11, total reward = 10,
# ep = 43, steps = 9, total reward = 12,
# ep = 44, steps = 13, total reward = 8,
# ep = 45, steps = 16, total reward = 5,
# ep = 46, steps = 14, total reward = 7,
# ep = 47, steps = 14, total reward = 7,
# ep = 48, steps = 17, total reward = 4,
# ep = 49, steps = 10, total reward = 11,
# ep = 50, steps = 16, total reward = 5,
# ep = 51, steps = 66, total reward = -54,
# ep = 52, steps = 16, total reward = 5,
# ep = 53, steps = 10, total reward = 11,
# ep = 54, steps = 6, total reward = 15,
# ep = 55, steps = 20, total reward = 1,
# ep = 56, steps = 11, total reward = 10,
# ep = 57, steps = 10, total reward = 11,
# ep = 58, steps = 9, total reward = 12,
# ep = 59, steps = 12, total reward = 9,
# ep = 60, steps = 9, total reward = 12,
# ep = 61, steps = 17, total reward = 4,
# ep = 62, steps = 15, total reward = 6,
# ep = 63, steps = 17, total reward = 4,
# ep = 64, steps = 13, total reward = 8,
# ep = 65, steps = 16, total reward = 5,
# ep = 66, steps = 11, total reward = 10,
# ep = 67, steps = 29, total reward = -17,
# ep = 68, steps = 10, total reward = 11,
# ep = 69, steps = 10, total reward = 11,
# ep = 70, steps = 10, total reward = 11,
# ep = 71, steps = 16, total reward = 5,
# ep = 72, steps = 11, total reward = 10,
# ep = 73, steps = 12, total reward = 9,
# ep = 74, steps = 12, total reward = 9,
# ep = 75, steps = 17, total reward = -5,
# ep = 76, steps = 13, total reward = 8,
# ep = 77, steps = 15, total reward = 6,
# ep = 78, steps = 12, total reward = 9,
# ep = 79, steps = 17, total reward = 4,
# ep = 80, steps = 13, total reward = 8,
# ep = 81, steps = 15, total reward = 6,
# ep = 82, steps = 12, total reward = 9,
# ep = 83, steps = 9, total reward = 12,
# ep = 84, steps = 13, total reward = 8,
# ep = 85, steps = 17, total reward = 4,
# ep = 86, steps = 14, total reward = 7,
# ep = 87, steps = 14, total reward = 7,
# ep = 88, steps = 12, total reward = 9,
# ep = 89, steps = 12, total reward = 9,
# ep = 90, steps = 9, total reward = 12,
# ep = 91, steps = 12, total reward = 9,
# ep = 92, steps = 14, total reward = 7,
# ep = 93, steps = 11, total reward = 10,
# ep = 94, steps = 13, total reward = 8,
# ep = 95, steps = 10, total reward = 11,
# ep = 96, steps = 13, total reward = 8,
# ep = 97, steps = 13, total reward = 8,
# ep = 98, steps = 14, total reward = 7,
# ep = 99, steps = 6, total reward = 15,
# ep = 100, steps = 10, total reward = 11,
# ep = 101, steps = 16, total reward = 5,
# ep = 102, steps = 12, total reward = 9,
# ep = 103, steps = 13, total reward = 8,
# ep = 104, steps = 10, total reward = 11,
# ep = 105, steps = 12, total reward = 9,
# ep = 106, steps = 18, total reward = 3,
# ep = 107, steps = 13, total reward = 8,
# ep = 108, steps = 10, total reward = 11,
# ep = 109, steps = 11, total reward = 10,
# ep = 110, steps = 14, total reward = 7,
# ep = 111, steps = 14, total reward = 7,
# ep = 112, steps = 12, total reward = 9,
# ep = 113, steps = 9, total reward = 12,
# ep = 114, steps = 14, total reward = 7,
# ep = 115, steps = 11, total reward = 10,
# ep = 116, steps = 15, total reward = 6,
# ep = 117, steps = 10, total reward = 11,
# ep = 118, steps = 8, total reward = 13,
# ep = 119, steps = 18, total reward = 3,
# ep = 120, steps = 16, total reward = 5,
# ep = 121, steps = 13, total reward = 8,
# ep = 122, steps = 17, total reward = 4,
# ep = 123, steps = 15, total reward = 6,
# ep = 124, steps = 13, total reward = 8,
# ep = 125, steps = 13, total reward = 8,
# ep = 126, steps = 16, total reward = 5,
# ep = 127, steps = 13, total reward = 8,
# ep = 128, steps = 15, total reward = 6,
# ep = 129, steps = 18, total reward = 3,
# ep = 130, steps = 11, total reward = 10,
# ep = 131, steps = 14, total reward = 7,
# ep = 132, steps = 16, total reward = 5,
# ep = 133, steps = 13, total reward = 8,
# ep = 134, steps = 14, total reward = 7,
# ep = 135, steps = 14, total reward = 7,
# ep = 136, steps = 13, total reward = 8,
# ep = 137, steps = 6, total reward = 15,
# ep = 138, steps = 17, total reward = 4,
# ep = 139, steps = 14, total reward = 7,
# ep = 140, steps = 12, total reward = 9,
# ep = 141, steps = 15, total reward = 6,
# ep = 142, steps = 8, total reward = 13,
# ep = 143, steps = 10, total reward = 11,
# ep = 144, steps = 12, total reward = 9,
# ep = 145, steps = 17, total reward = 4,
# ep = 146, steps = 12, total reward = 9,
# ep = 147, steps = 7, total reward = 14,
# ep = 148, steps = 9, total reward = 12,
# ep = 149, steps = 10, total reward = 11,
# ep = 150, steps = 17, total reward = 4,
# ep = 151, steps = 13, total reward = 8,
# ep = 152, steps = 18, total reward = 3,
# ep = 153, steps = 14, total reward = 7,
# ep = 154, steps = 14, total reward = 7,
# ep = 155, steps = 18, total reward = 3,
# ep = 156, steps = 17, total reward = 4,
# ep = 157, steps = 11, total reward = 10,
# ep = 158, steps = 14, total reward = -2,
# ep = 159, steps = 14, total reward = 7,
# ep = 160, steps = 17, total reward = 4,
# ep = 161, steps = 12, total reward = 9,
# ep = 162, steps = 13, total reward = 8,
# ep = 163, steps = 15, total reward = 6,
# ep = 164, steps = 14, total reward = 7,
# ep = 165, steps = 13, total reward = 8,
# ep = 166, steps = 13, total reward = 8,
# ep = 167, steps = 14, total reward = 7,
# ep = 168, steps = 13, total reward = 8,
# ep = 169, steps = 13, total reward = 8,
# ep = 170, steps = 15, total reward = 6,
# ep = 171, steps = 13, total reward = 8,
# ep = 172, steps = 15, total reward = -3,
# ep = 173, steps = 15, total reward = 6,
# ep = 174, steps = 16, total reward = 5,
# ep = 175, steps = 11, total reward = 10,
# ep = 176, steps = 9, total reward = 12,
# ep = 177, steps = 12, total reward = 9,
# ep = 178, steps = 10, total reward = 11,
# ep = 179, steps = 16, total reward = 5,
# ep = 180, steps = 13, total reward = 8,
# ep = 181, steps = 15, total reward = 6,
# ep = 182, steps = 8, total reward = 13,
# ep = 183, steps = 13, total reward = 8,
# ep = 184, steps = 17, total reward = 4,
# ep = 185, steps = 14, total reward = 7,
# ep = 186, steps = 17, total reward = 4,
# ep = 187, steps = 15, total reward = 6,
# ep = 188, steps = 12, total reward = 9,
# ep = 189, steps = 14, total reward = 7,
# ep = 190, steps = 17, total reward = -5,
# ep = 191, steps = 16, total reward = 5,
# ep = 192, steps = 15, total reward = 6,
# ep = 193, steps = 12, total reward = 9,
# ep = 194, steps = 15, total reward = 6,
# ep = 195, steps = 11, total reward = 10,
# ep = 196, steps = 10, total reward = 11,
# ep = 197, steps = 14, total reward = 7,
# ep = 198, steps = 14, total reward = 7,
# ep = 199, steps = 8, total reward = 13,
# ep = 200, steps = 15, total reward = 6,
# ep = 201, steps = 8, total reward = 13,
# ep = 202, steps = 12, total reward = 9,
# ep = 203, steps = 10, total reward = 11,
# ep = 204, steps = 12, total reward = 9,
# ep = 205, steps = 15, total reward = 6,
# ep = 206, steps = 17, total reward = 4,
# ep = 207, steps = 18, total reward = -6,
# ep = 208, steps = 13, total reward = 8,
# ep = 209, steps = 15, total reward = 6,
# ep = 210, steps = 12, total reward = 9,
# ep = 211, steps = 12, total reward = 9,
# ep = 212, steps = 12, total reward = 9,
# ep = 213, steps = 13, total reward = -1,
# ep = 214, steps = 11, total reward = 10,
# ep = 215, steps = 8, total reward = 13,
# ep = 216, steps = 11, total reward = 10,
# ep = 217, steps = 13, total reward = 8,
# ep = 218, steps = 15, total reward = 6,
# ep = 219, steps = 16, total reward = 5,
# ep = 220, steps = 11, total reward = 10,
# ep = 221, steps = 17, total reward = 4,
# ep = 222, steps = 11, total reward = 10,
# ep = 223, steps = 12, total reward = 9,
# ep = 224, steps = 12, total reward = 9,
# ep = 225, steps = 10, total reward = 11,
# ep = 226, steps = 13, total reward = 8,
# ep = 227, steps = 6, total reward = 15,
# ep = 228, steps = 12, total reward = 9,
# ep = 229, steps = 13, total reward = 8,
# ep = 230, steps = 12, total reward = 9,
# ep = 231, steps = 13, total reward = 8,
# ep = 232, steps = 12, total reward = 9,
# ep = 233, steps = 13, total reward = 8,
# ep = 234, steps = 16, total reward = 5,
# ep = 235, steps = 15, total reward = 6,
# ep = 236, steps = 13, total reward = 8,
# ep = 237, steps = 13, total reward = 8,
# ep = 238, steps = 14, total reward = 7,
# ep = 239, steps = 9, total reward = 12,
# ep = 240, steps = 18, total reward = 3,
# ep = 241, steps = 15, total reward = 6,
# ep = 242, steps = 15, total reward = 6,
# ep = 243, steps = 13, total reward = 8,
# ep = 244, steps = 13, total reward = 8,
# ep = 245, steps = 11, total reward = 1,
# ep = 246, steps = 11, total reward = 10,
# ep = 247, steps = 14, total reward = 7,
# ep = 248, steps = 13, total reward = 8,
# ep = 249, steps = 16, total reward = 5,
# ep = 250, steps = 11, total reward = 10,
# ep = 251, steps = 15, total reward = 6,
# ep = 252, steps = 14, total reward = 7,
# ep = 253, steps = 13, total reward = 8,
# ep = 254, steps = 14, total reward = 7,
# ep = 255, steps = 15, total reward = 6,
# ep = 256, steps = 16, total reward = 5,
# ep = 257, steps = 13, total reward = 8,
# ep = 258, steps = 11, total reward = 10,
# ep = 259, steps = 16, total reward = 5,
# ep = 260, steps = 18, total reward = 3,
# ep = 261, steps = 18, total reward = 3,
# ep = 262, steps = 14, total reward = 7,
# ep = 263, steps = 14, total reward = 7,
# ep = 264, steps = 13, total reward = 8,
# ep = 265, steps = 10, total reward = 11,
# ep = 266, steps = 16, total reward = 5,
# ep = 267, steps = 11, total reward = 10,
# ep = 268, steps = 15, total reward = 6,
# ep = 269, steps = 11, total reward = 10,
# ep = 270, steps = 10, total reward = 11,
# ep = 271, steps = 9, total reward = 12,
# ep = 272, steps = 17, total reward = -5,
# ep = 273, steps = 11, total reward = 10,
# ep = 274, steps = 12, total reward = 9,
# ep = 275, steps = 13, total reward = 8,
# ep = 276, steps = 13, total reward = 8,
# ep = 277, steps = 15, total reward = 6,
# ep = 278, steps = 37, total reward = -25,
# ep = 279, steps = 12, total reward = 9,
# ep = 280, steps = 14, total reward = 7,
# ep = 281, steps = 9, total reward = 12,
# ep = 282, steps = 15, total reward = 6,
# ep = 283, steps = 13, total reward = 8,
# ep = 284, steps = 13, total reward = 8,
# ep = 285, steps = 16, total reward = 5,
# ep = 286, steps = 9, total reward = 12,
# ep = 287, steps = 15, total reward = 6,
# ep = 288, steps = 15, total reward = 6,
# ep = 289, steps = 15, total reward = 6,
# ep = 290, steps = 13, total reward = 8,
# ep = 291, steps = 14, total reward = 7,
# ep = 292, steps = 12, total reward = 9,
# ep = 293, steps = 12, total reward = 9,
# ep = 294, steps = 10, total reward = 11,
# ep = 295, steps = 16, total reward = 5,
# ep = 296, steps = 14, total reward = 7,
# ep = 297, steps = 12, total reward = 9,
# ep = 298, steps = 16, total reward = 5,
# ep = 299, steps = 12, total reward = 9,
# ep = 300, steps = 11, total reward = 10,
# ep = 301, steps = 13, total reward = 8,
# ep = 302, steps = 8, total reward = 13,
# ep = 303, steps = 15, total reward = 6,
# ep = 304, steps = 18, total reward = 3,
# ep = 305, steps = 16, total reward = 5,
# ep = 306, steps = 15, total reward = 6,
# ep = 307, steps = 17, total reward = 4,
# ep = 308, steps = 24, total reward = -3,
# ep = 309, steps = 10, total reward = 11,
# ep = 310, steps = 12, total reward = 9,
# ep = 311, steps = 12, total reward = 0,
# ep = 312, steps = 17, total reward = 4,
# ep = 313, steps = 15, total reward = 6,
# ep = 314, steps = 15, total reward = 6,
# ep = 315, steps = 11, total reward = 10,
# ep = 316, steps = 20, total reward = 1,
# ep = 317, steps = 9, total reward = 12,
# ep = 318, steps = 13, total reward = 8,
# ep = 319, steps = 18, total reward = 3,
# ep = 320, steps = 14, total reward = 7,
# ep = 321, steps = 10, total reward = 11,
# ep = 322, steps = 10, total reward = 11,
# ep = 323, steps = 12, total reward = 9,
# ep = 324, steps = 12, total reward = 9,
# ep = 325, steps = 6, total reward = 15,
# ep = 326, steps = 10, total reward = 11,
# ep = 327, steps = 13, total reward = 8,
# ep = 328, steps = 7, total reward = 14,
# ep = 329, steps = 15, total reward = 6,
# ep = 330, steps = 14, total reward = 7,
# ep = 331, steps = 10, total reward = 11,
# ep = 332, steps = 13, total reward = 8,
# ep = 333, steps = 11, total reward = 10,
# ep = 334, steps = 18, total reward = 3,
# ep = 335, steps = 14, total reward = 7,
# ep = 336, steps = 16, total reward = 5,
# ep = 337, steps = 12, total reward = 9,
# ep = 338, steps = 12, total reward = 9,
# ep = 339, steps = 9, total reward = 12,
# ep = 340, steps = 15, total reward = 6,
# ep = 341, steps = 14, total reward = 7,
# ep = 342, steps = 16, total reward = 5,
# ep = 343, steps = 10, total reward = 11,
# ep = 344, steps = 15, total reward = 6,
# ep = 345, steps = 9, total reward = 12,
# ep = 346, steps = 15, total reward = 6,
# ep = 347, steps = 14, total reward = 7,
# ep = 348, steps = 8, total reward = 13,
# ep = 349, steps = 12, total reward = 9,
# ep = 350, steps = 10, total reward = 11,
# ep = 351, steps = 12, total reward = 9,
# ep = 352, steps = 11, total reward = 10,
# ep = 353, steps = 14, total reward = 7,
# ep = 354, steps = 12, total reward = 9,
# ep = 355, steps = 18, total reward = -6,
# ep = 356, steps = 18, total reward = -6,
# ep = 357, steps = 17, total reward = 4,
# ep = 358, steps = 12, total reward = 9,
# ep = 359, steps = 13, total reward = 8,
# ep = 360, steps = 10, total reward = 11,
# ep = 361, steps = 13, total reward = 8,
# ep = 362, steps = 12, total reward = 9,
# ep = 363, steps = 15, total reward = 6,
# ep = 364, steps = 17, total reward = 4,
# ep = 365, steps = 11, total reward = 10,
# ep = 366, steps = 9, total reward = 12,
# ep = 367, steps = 18, total reward = 3,
# ep = 368, steps = 12, total reward = 9,
# ep = 369, steps = 14, total reward = 7,
# ep = 370, steps = 16, total reward = 5,
# ep = 371, steps = 10, total reward = 11,
# ep = 372, steps = 12, total reward = 9,
# ep = 373, steps = 15, total reward = 6,
# ep = 374, steps = 17, total reward = 4,
# ep = 375, steps = 14, total reward = 7,
# ep = 376, steps = 11, total reward = 10,
# ep = 377, steps = 17, total reward = 4,
# ep = 378, steps = 13, total reward = 8,
# ep = 379, steps = 13, total reward = 8,
# ep = 380, steps = 16, total reward = 5,
# ep = 381, steps = 10, total reward = 11,
# ep = 382, steps = 17, total reward = 4,
# ep = 383, steps = 15, total reward = 6,
# ep = 384, steps = 10, total reward = 11,
# ep = 385, steps = 11, total reward = 10,
# ep = 386, steps = 12, total reward = 9,
# ep = 387, steps = 15, total reward = 6,
# ep = 388, steps = 11, total reward = 10,
# ep = 389, steps = 15, total reward = 6,
# ep = 390, steps = 12, total reward = 9,
# ep = 391, steps = 14, total reward = 7,
# ep = 392, steps = 18, total reward = 3,
# ep = 393, steps = 13, total reward = 8,
# ep = 394, steps = 16, total reward = 5,
# ep = 395, steps = 14, total reward = 7,
# ep = 396, steps = 17, total reward = 4,
# ep = 397, steps = 13, total reward = 8,
# ep = 398, steps = 11, total reward = 10,
# ep = 399, steps = 15, total reward = 6,
# ep = 400, steps = 14, total reward = 7,
# ep = 401, steps = 12, total reward = 9,
# ep = 402, steps = 15, total reward = 6,
# ep = 403, steps = 18, total reward = 3,
# ep = 404, steps = 13, total reward = 8,
# ep = 405, steps = 15, total reward = 6,
# ep = 406, steps = 13, total reward = 8,
# ep = 407, steps = 17, total reward = -5,
# ep = 408, steps = 16, total reward = 5,
# ep = 409, steps = 11, total reward = 10,
# ep = 410, steps = 11, total reward = 10,
# ep = 411, steps = 11, total reward = 10,
# ep = 412, steps = 14, total reward = 7,
# ep = 413, steps = 11, total reward = 10,
# ep = 414, steps = 16, total reward = 5,
# ep = 415, steps = 16, total reward = 5,
# ep = 416, steps = 6, total reward = 15,
# ep = 417, steps = 7, total reward = 14,
# ep = 418, steps = 13, total reward = 8,
# ep = 419, steps = 11, total reward = 10,
# ep = 420, steps = 12, total reward = 9,
# ep = 421, steps = 16, total reward = 5,
# ep = 422, steps = 15, total reward = 6,
# ep = 423, steps = 10, total reward = 11,
# ep = 424, steps = 15, total reward = 6,
# ep = 425, steps = 13, total reward = 8,
# ep = 426, steps = 16, total reward = 5,
# ep = 427, steps = 16, total reward = 5,
# ep = 428, steps = 13, total reward = 8,
# ep = 429, steps = 17, total reward = 4,
# ep = 430, steps = 16, total reward = -4,
# ep = 431, steps = 16, total reward = 5,
# ep = 432, steps = 16, total reward = 5,
# ep = 433, steps = 16, total reward = 5,
# ep = 434, steps = 8, total reward = 13,
# ep = 435, steps = 15, total reward = 6,
# ep = 436, steps = 13, total reward = 8,
# ep = 437, steps = 16, total reward = 5,
# ep = 438, steps = 10, total reward = 11,
# ep = 439, steps = 13, total reward = 8,
# ep = 440, steps = 14, total reward = 7,
# ep = 441, steps = 10, total reward = 11,
# ep = 442, steps = 12, total reward = 9,
# ep = 443, steps = 16, total reward = 5,
# ep = 444, steps = 12, total reward = 9,
# ep = 445, steps = 10, total reward = 11,
# ep = 446, steps = 10, total reward = 11,
# ep = 447, steps = 13, total reward = -1,
# ep = 448, steps = 12, total reward = 9,
# ep = 449, steps = 13, total reward = 8,
# ep = 450, steps = 13, total reward = 8,
# ep = 451, steps = 17, total reward = 4,
# ep = 452, steps = 15, total reward = 6,
# ep = 453, steps = 11, total reward = 10,
# ep = 454, steps = 17, total reward = 4,
# ep = 455, steps = 9, total reward = 12,
# ep = 456, steps = 8, total reward = 13,
# ep = 457, steps = 11, total reward = 10,
# ep = 458, steps = 19, total reward = -7,
# ep = 459, steps = 13, total reward = 8,
# ep = 460, steps = 15, total reward = 6,
# ep = 461, steps = 11, total reward = 10,
# ep = 462, steps = 13, total reward = 8,
# ep = 463, steps = 16, total reward = 5,
# ep = 464, steps = 12, total reward = 9,
# ep = 465, steps = 13, total reward = 8,
# ep = 466, steps = 13, total reward = 8,
# ep = 467, steps = 14, total reward = 7,
# ep = 468, steps = 14, total reward = 7,
# ep = 469, steps = 13, total reward = 8,
# ep = 470, steps = 16, total reward = 5,
# ep = 471, steps = 14, total reward = 7,
# ep = 472, steps = 14, total reward = 7,
# ep = 473, steps = 13, total reward = 8,
# ep = 474, steps = 15, total reward = 6,
# ep = 475, steps = 10, total reward = 11,
# ep = 476, steps = 9, total reward = 12,
# ep = 477, steps = 11, total reward = 10,
# ep = 478, steps = 16, total reward = 5,
# ep = 479, steps = 14, total reward = 7,
# ep = 480, steps = 7, total reward = 14,
# ep = 481, steps = 10, total reward = 11,
# ep = 482, steps = 14, total reward = 7,
# ep = 483, steps = 14, total reward = 7,
# ep = 484, steps = 18, total reward = 3,
# ep = 485, steps = 12, total reward = 9,
# ep = 486, steps = 11, total reward = 10,
# ep = 487, steps = 17, total reward = 4,
# ep = 488, steps = 16, total reward = 5,
# ep = 489, steps = 10, total reward = 11,
# ep = 490, steps = 15, total reward = 6,
# ep = 491, steps = 10, total reward = 11,
# ep = 492, steps = 14, total reward = 7,
# ep = 493, steps = 17, total reward = 4,
# ep = 494, steps = 13, total reward = 8,
# ep = 495, steps = 15, total reward = 6,
# ep = 496, steps = 13, total reward = 8,
# ep = 497, steps = 16, total reward = 5,
# ep = 498, steps = 17, total reward = 4,
# ep = 499, steps = 12, total reward = 9,
# ep = 500, steps = 15, total reward = 6,
# ep = 501, steps = 11, total reward = 10,
# ep = 502, steps = 16, total reward = 5,
# ep = 503, steps = 8, total reward = 13,
# ep = 504, steps = 16, total reward = 5,
# ep = 505, steps = 15, total reward = 6,
# ep = 506, steps = 12, total reward = 9,
# ep = 507, steps = 7, total reward = 14,
# ep = 508, steps = 9, total reward = 12,
# ep = 509, steps = 13, total reward = 8,
# ep = 510, steps = 11, total reward = 10,
# ep = 511, steps = 10, total reward = 11,
# ep = 512, steps = 15, total reward = 6,
# ep = 513, steps = 17, total reward = 4,
# ep = 514, steps = 13, total reward = 8,
# ep = 515, steps = 10, total reward = 11,
# ep = 516, steps = 15, total reward = 6,
# ep = 517, steps = 13, total reward = 8,
# ep = 518, steps = 15, total reward = 6,
# ep = 519, steps = 11, total reward = 10,
# ep = 520, steps = 15, total reward = 6,
# ep = 521, steps = 11, total reward = 10,
# ep = 522, steps = 18, total reward = 3,
# ep = 523, steps = 16, total reward = 5,
# ep = 524, steps = 12, total reward = 9,
# ep = 525, steps = 12, total reward = 9,
# ep = 526, steps = 18, total reward = 3,
# ep = 527, steps = 14, total reward = 7,
# ep = 528, steps = 8, total reward = 13,
# ep = 529, steps = 13, total reward = 8,
# ep = 530, steps = 15, total reward = 6,
# ep = 531, steps = 16, total reward = 5,
# ep = 532, steps = 13, total reward = 8,
# ep = 533, steps = 14, total reward = 7,
# ep = 534, steps = 13, total reward = 8,
# ep = 535, steps = 16, total reward = 5,
# ep = 536, steps = 14, total reward = 7,
# ep = 537, steps = 17, total reward = -5,
# ep = 538, steps = 13, total reward = 8,
# ep = 539, steps = 10, total reward = 11,
# ep = 540, steps = 12, total reward = 9,
# ep = 541, steps = 12, total reward = 9,
# ep = 542, steps = 13, total reward = 8,
# ep = 543, steps = 13, total reward = 8,
# ep = 544, steps = 17, total reward = 4,
# ep = 545, steps = 11, total reward = 10,
# ep = 546, steps = 16, total reward = 5,
# ep = 547, steps = 13, total reward = 8,
# ep = 548, steps = 12, total reward = 9,
# ep = 549, steps = 14, total reward = 7,
# ep = 550, steps = 14, total reward = 7,
# ep = 551, steps = 8, total reward = 13,
# ep = 552, steps = 16, total reward = 5,
# ep = 553, steps = 14, total reward = 7,
# ep = 554, steps = 15, total reward = 6,
# ep = 555, steps = 11, total reward = 10,
# ep = 556, steps = 11, total reward = 10,
# ep = 557, steps = 14, total reward = 7,
# ep = 558, steps = 15, total reward = 6,
# ep = 559, steps = 13, total reward = 8,
# ep = 560, steps = 10, total reward = 11,
# ep = 561, steps = 11, total reward = 10,
# ep = 562, steps = 20, total reward = 1,
# ep = 563, steps = 15, total reward = 6,
# ep = 564, steps = 11, total reward = 10,
# ep = 565, steps = 18, total reward = 3,
# ep = 566, steps = 14, total reward = 7,
# ep = 567, steps = 14, total reward = 7,
# ep = 568, steps = 14, total reward = 7,
# ep = 569, steps = 14, total reward = 7,
# ep = 570, steps = 10, total reward = 11,
# ep = 571, steps = 14, total reward = 7,
# ep = 572, steps = 21, total reward = 0,
# ep = 573, steps = 15, total reward = 6,
# ep = 574, steps = 14, total reward = 7,
# ep = 575, steps = 10, total reward = 11,
# ep = 576, steps = 11, total reward = 10,
# ep = 577, steps = 16, total reward = 5,
# ep = 578, steps = 12, total reward = 9,
# ep = 579, steps = 16, total reward = 5,
# ep = 580, steps = 13, total reward = 8,
# ep = 581, steps = 11, total reward = 10,
# ep = 582, steps = 13, total reward = 8,
# ep = 583, steps = 12, total reward = 9,
# ep = 584, steps = 16, total reward = 5,
# ep = 585, steps = 15, total reward = 6,
# ep = 586, steps = 16, total reward = 5,
# ep = 587, steps = 9, total reward = 12,
# ep = 588, steps = 11, total reward = 10,
# ep = 589, steps = 13, total reward = 8,
# ep = 590, steps = 17, total reward = 4,
# ep = 591, steps = 14, total reward = 7,
# ep = 592, steps = 10, total reward = 11,
# ep = 593, steps = 17, total reward = 4,
# ep = 594, steps = 8, total reward = 13,
# ep = 595, steps = 13, total reward = 8,
# ep = 596, steps = 11, total reward = 10,
# ep = 597, steps = 18, total reward = 3,
# ep = 598, steps = 15, total reward = 6,
# ep = 599, steps = 9, total reward = 12,
# ep = 600, steps = 17, total reward = 4,
# ep = 601, steps = 13, total reward = 8,
# ep = 602, steps = 16, total reward = 5,
# ep = 603, steps = 6, total reward = 15,
# ep = 604, steps = 15, total reward = 6,
# ep = 605, steps = 14, total reward = 7,
# ep = 606, steps = 16, total reward = 5,
# ep = 607, steps = 15, total reward = 6,
# ep = 608, steps = 14, total reward = 7,
# ep = 609, steps = 21, total reward = 0,
# ep = 610, steps = 13, total reward = 8,
# ep = 611, steps = 13, total reward = 8,
# ep = 612, steps = 14, total reward = 7,
# ep = 613, steps = 16, total reward = -4,
# ep = 614, steps = 14, total reward = 7,
# ep = 615, steps = 12, total reward = 9,
# ep = 616, steps = 13, total reward = 8,
# ep = 617, steps = 12, total reward = 9,
# ep = 618, steps = 11, total reward = 10,
# ep = 619, steps = 12, total reward = 9,
# ep = 620, steps = 15, total reward = 6,
# ep = 621, steps = 15, total reward = 6,
# ep = 622, steps = 10, total reward = 11,
# ep = 623, steps = 12, total reward = 9,
# ep = 624, steps = 14, total reward = 7,
# ep = 625, steps = 13, total reward = 8,
# ep = 626, steps = 16, total reward = 5,
# ep = 627, steps = 15, total reward = 6,
# ep = 628, steps = 10, total reward = 11,
# ep = 629, steps = 8, total reward = 13,
# ep = 630, steps = 17, total reward = 4,
# ep = 631, steps = 14, total reward = 7,
# ep = 632, steps = 11, total reward = 10,
# ep = 633, steps = 10, total reward = 11,
# ep = 634, steps = 17, total reward = -5,
# ep = 635, steps = 18, total reward = 3,
# ep = 636, steps = 14, total reward = 7,
# ep = 637, steps = 13, total reward = -1,
# ep = 638, steps = 18, total reward = 3,
# ep = 639, steps = 11, total reward = 10,
# ep = 640, steps = 10, total reward = 11,
# ep = 641, steps = 11, total reward = 10,
# ep = 642, steps = 12, total reward = 9,
# ep = 643, steps = 16, total reward = 5,
# ep = 644, steps = 16, total reward = 5,
# ep = 645, steps = 15, total reward = 6,
# ep = 646, steps = 13, total reward = 8,
# ep = 647, steps = 7, total reward = 14,
# ep = 648, steps = 14, total reward = 7,
# ep = 649, steps = 11, total reward = 10,
# ep = 650, steps = 12, total reward = 9,
# ep = 651, steps = 16, total reward = 5,
# ep = 652, steps = 12, total reward = 9,
# ep = 653, steps = 16, total reward = 5,
# ep = 654, steps = 10, total reward = 11,
# ep = 655, steps = 18, total reward = 3,
# ep = 656, steps = 9, total reward = 3,
# ep = 657, steps = 14, total reward = 7,
# ep = 658, steps = 8, total reward = 13,
# ep = 659, steps = 16, total reward = 5,
# ep = 660, steps = 15, total reward = 6,
# ep = 661, steps = 14, total reward = 7,
# ep = 662, steps = 13, total reward = 8,
# ep = 663, steps = 14, total reward = 7,
# ep = 664, steps = 10, total reward = 11,
# ep = 665, steps = 16, total reward = 5,
# ep = 666, steps = 12, total reward = 9,
# ep = 667, steps = 12, total reward = 9,
# ep = 668, steps = 9, total reward = 12,
# ep = 669, steps = 15, total reward = 6,
# ep = 670, steps = 12, total reward = 9,
# ep = 671, steps = 14, total reward = 7,
# ep = 672, steps = 15, total reward = 6,
# ep = 673, steps = 15, total reward = 6,
# ep = 674, steps = 18, total reward = 3,
# ep = 675, steps = 12, total reward = 9,
# ep = 676, steps = 15, total reward = 6,
# ep = 677, steps = 13, total reward = 8,
# ep = 678, steps = 11, total reward = 10,
# ep = 679, steps = 11, total reward = 10,
# ep = 680, steps = 10, total reward = 11,
# ep = 681, steps = 14, total reward = 7,
# ep = 682, steps = 13, total reward = 8,
# ep = 683, steps = 8, total reward = 13,
# ep = 684, steps = 13, total reward = 8,
# ep = 685, steps = 11, total reward = 10,
# ep = 686, steps = 16, total reward = 5,
# ep = 687, steps = 16, total reward = -4,
# ep = 688, steps = 9, total reward = 12,
# ep = 689, steps = 12, total reward = 9,
# ep = 690, steps = 18, total reward = 3,
# ep = 691, steps = 6, total reward = 15,
# ep = 692, steps = 12, total reward = 0,
# ep = 693, steps = 18, total reward = 3,
# ep = 694, steps = 15, total reward = 6,
# ep = 695, steps = 18, total reward = 3,
# ep = 696, steps = 10, total reward = 11,
# ep = 697, steps = 11, total reward = 10,
# ep = 698, steps = 18, total reward = 3,
# ep = 699, steps = 18, total reward = 3,
# ep = 700, steps = 11, total reward = 10,
# ep = 701, steps = 15, total reward = 6,
# ep = 702, steps = 16, total reward = 5,
# ep = 703, steps = 10, total reward = 11,
# ep = 704, steps = 12, total reward = 9,
# ep = 705, steps = 11, total reward = 10,
# ep = 706, steps = 7, total reward = 14,
# ep = 707, steps = 10, total reward = 11,
# ep = 708, steps = 9, total reward = 12,
# ep = 709, steps = 16, total reward = 5,
# ep = 710, steps = 14, total reward = 7,
# ep = 711, steps = 12, total reward = 9,
# ep = 712, steps = 17, total reward = 4,
# ep = 713, steps = 14, total reward = 7,
# ep = 714, steps = 11, total reward = 10,
# ep = 715, steps = 11, total reward = 10,
# ep = 716, steps = 12, total reward = 9,
# ep = 717, steps = 9, total reward = 12,
# ep = 718, steps = 13, total reward = 8,
# ep = 719, steps = 6, total reward = 15,
# ep = 720, steps = 10, total reward = 11,
# ep = 721, steps = 15, total reward = 6,
# ep = 722, steps = 16, total reward = -4,
# ep = 723, steps = 10, total reward = 11,
# ep = 724, steps = 16, total reward = 5,
# ep = 725, steps = 16, total reward = 5,
# ep = 726, steps = 18, total reward = 3,
# ep = 727, steps = 15, total reward = 6,
# ep = 728, steps = 17, total reward = 4,
# ep = 729, steps = 14, total reward = 7,
# ep = 730, steps = 13, total reward = 8,
# ep = 731, steps = 17, total reward = 4,
# ep = 732, steps = 11, total reward = 10,
# ep = 733, steps = 6, total reward = 15,
# ep = 734, steps = 8, total reward = 13,
# ep = 735, steps = 12, total reward = 9,
# ep = 736, steps = 13, total reward = 8,
# ep = 737, steps = 7, total reward = 14,
# ep = 738, steps = 16, total reward = 5,
# ep = 739, steps = 12, total reward = 9,
# ep = 740, steps = 13, total reward = 8,
# ep = 741, steps = 16, total reward = -4,
# ep = 742, steps = 18, total reward = 3,
# ep = 743, steps = 17, total reward = 4,
# ep = 744, steps = 17, total reward = 4,
# ep = 745, steps = 15, total reward = 6,
# ep = 746, steps = 13, total reward = 8,
# ep = 747, steps = 15, total reward = 6,
# ep = 748, steps = 14, total reward = 7,
# ep = 749, steps = 16, total reward = 5,
# ep = 750, steps = 12, total reward = 9,
# ep = 751, steps = 15, total reward = 6,
# ep = 752, steps = 15, total reward = 6,
# ep = 753, steps = 17, total reward = 4,
# ep = 754, steps = 13, total reward = 8,
# ep = 755, steps = 14, total reward = 7,
# ep = 756, steps = 12, total reward = 9,
# ep = 757, steps = 16, total reward = 5,
# ep = 758, steps = 14, total reward = -2,
# ep = 759, steps = 17, total reward = 4,
# ep = 760, steps = 13, total reward = 8,
# ep = 761, steps = 12, total reward = 9,
# ep = 762, steps = 8, total reward = 13,
# ep = 763, steps = 13, total reward = 8,
# ep = 764, steps = 11, total reward = 10,
# ep = 765, steps = 14, total reward = 7,
# ep = 766, steps = 17, total reward = 4,
# ep = 767, steps = 14, total reward = 7,
# ep = 768, steps = 12, total reward = 9,
# ep = 769, steps = 10, total reward = 11,
# ep = 770, steps = 10, total reward = 11,
# ep = 771, steps = 12, total reward = 9,
# ep = 772, steps = 20, total reward = 1,
# ep = 773, steps = 14, total reward = 7,
# ep = 774, steps = 12, total reward = 9,
# ep = 775, steps = 15, total reward = 6,
# ep = 776, steps = 12, total reward = 9,
# ep = 777, steps = 11, total reward = 10,
# ep = 778, steps = 12, total reward = 9,
# ep = 779, steps = 12, total reward = 9,
# ep = 780, steps = 12, total reward = 9,
# ep = 781, steps = 17, total reward = 4,
# ep = 782, steps = 15, total reward = 6,
# ep = 783, steps = 13, total reward = 8,
# ep = 784, steps = 6, total reward = 15,
# ep = 785, steps = 11, total reward = 10,
# ep = 786, steps = 14, total reward = 7,
# ep = 787, steps = 13, total reward = 8,
# ep = 788, steps = 7, total reward = 14,
# ep = 789, steps = 16, total reward = 5,
# ep = 790, steps = 14, total reward = 7,
# ep = 791, steps = 13, total reward = 8,
# ep = 792, steps = 15, total reward = 6,
# ep = 793, steps = 14, total reward = 7,
# ep = 794, steps = 16, total reward = 5,
# ep = 795, steps = 15, total reward = -3,
# ep = 796, steps = 13, total reward = 8,
# ep = 797, steps = 13, total reward = 8,
# ep = 798, steps = 15, total reward = 6,
# ep = 799, steps = 8, total reward = 13,
# ep = 800, steps = 16, total reward = 5,
# ep = 801, steps = 12, total reward = 9,
# ep = 802, steps = 15, total reward = 6,
# ep = 803, steps = 12, total reward = 9,
# ep = 804, steps = 10, total reward = 11,
# ep = 805, steps = 11, total reward = 10,
# ep = 806, steps = 14, total reward = 7,
# ep = 807, steps = 12, total reward = 9,
# ep = 808, steps = 15, total reward = 6,
# ep = 809, steps = 13, total reward = 8,
# ep = 810, steps = 12, total reward = 9,
# ep = 811, steps = 15, total reward = 6,
# ep = 812, steps = 11, total reward = 10,
# ep = 813, steps = 11, total reward = 10,
# ep = 814, steps = 17, total reward = 4,
# ep = 815, steps = 9, total reward = 12,
# ep = 816, steps = 14, total reward = 7,
# ep = 817, steps = 14, total reward = 7,
# ep = 818, steps = 14, total reward = 7,
# ep = 819, steps = 13, total reward = 8,
# ep = 820, steps = 13, total reward = 8,
# ep = 821, steps = 12, total reward = 9,
# ep = 822, steps = 8, total reward = 13,
# ep = 823, steps = 12, total reward = 9,
# ep = 824, steps = 13, total reward = 8,
# ep = 825, steps = 13, total reward = 8,
# ep = 826, steps = 15, total reward = -3,
# ep = 827, steps = 12, total reward = 9,
# ep = 828, steps = 10, total reward = 11,
# ep = 829, steps = 16, total reward = 5,
# ep = 830, steps = 13, total reward = 8,
# ep = 831, steps = 11, total reward = 10,
# ep = 832, steps = 13, total reward = 8,
# ep = 833, steps = 16, total reward = 5,
# ep = 834, steps = 12, total reward = 9,
# ep = 835, steps = 7, total reward = 14,
# ep = 836, steps = 18, total reward = 3,
# ep = 837, steps = 17, total reward = 4,
# ep = 838, steps = 18, total reward = 3,
# ep = 839, steps = 13, total reward = 8,
# ep = 840, steps = 15, total reward = 6,
# ep = 841, steps = 13, total reward = 8,
# ep = 842, steps = 15, total reward = 6,
# ep = 843, steps = 13, total reward = 8,
# ep = 844, steps = 11, total reward = 10,
# ep = 845, steps = 14, total reward = 7,
# ep = 846, steps = 11, total reward = 10,
# ep = 847, steps = 11, total reward = 10,
# ep = 848, steps = 12, total reward = 9,
# ep = 849, steps = 17, total reward = 4,
# ep = 850, steps = 15, total reward = 6,
# ep = 851, steps = 13, total reward = 8,
# ep = 852, steps = 9, total reward = 12,
# ep = 853, steps = 16, total reward = 5,
# ep = 854, steps = 13, total reward = 8,
# ep = 855, steps = 13, total reward = 8,
# ep = 856, steps = 14, total reward = 7,
# ep = 857, steps = 15, total reward = 6,
# ep = 858, steps = 15, total reward = 6,
# ep = 859, steps = 14, total reward = 7,
# ep = 860, steps = 12, total reward = 9,
# ep = 861, steps = 6, total reward = 15,
# ep = 862, steps = 8, total reward = 13,
# ep = 863, steps = 15, total reward = 6,
# ep = 864, steps = 17, total reward = 4,
# ep = 865, steps = 13, total reward = 8,
# ep = 866, steps = 11, total reward = 10,
# ep = 867, steps = 14, total reward = 7,
# ep = 868, steps = 16, total reward = 5,
# ep = 869, steps = 11, total reward = 10,
# ep = 870, steps = 14, total reward = 7,
# ep = 871, steps = 14, total reward = 7,
# ep = 872, steps = 7, total reward = 14,
# ep = 873, steps = 12, total reward = 9,
# ep = 874, steps = 14, total reward = 7,
# ep = 875, steps = 14, total reward = 7,
# ep = 876, steps = 9, total reward = 12,
# ep = 877, steps = 15, total reward = -3,
# ep = 878, steps = 17, total reward = 4,
# ep = 879, steps = 16, total reward = -4,
# ep = 880, steps = 12, total reward = 9,
# ep = 881, steps = 15, total reward = 6,
# ep = 882, steps = 14, total reward = 7,
# ep = 883, steps = 13, total reward = 8,
# ep = 884, steps = 15, total reward = 6,
# ep = 885, steps = 11, total reward = 10,
# ep = 886, steps = 11, total reward = 10,
# ep = 887, steps = 17, total reward = 4,
# ep = 888, steps = 11, total reward = 10,
# ep = 889, steps = 6, total reward = 15,
# ep = 890, steps = 10, total reward = 11,
# ep = 891, steps = 15, total reward = 6,
# ep = 892, steps = 17, total reward = 4,
# ep = 893, steps = 11, total reward = 10,
# ep = 894, steps = 8, total reward = 13,
# ep = 895, steps = 15, total reward = 6,
# ep = 896, steps = 14, total reward = 7,
# ep = 897, steps = 12, total reward = 9,
# ep = 898, steps = 18, total reward = 3,
# ep = 899, steps = 13, total reward = 8,
# ep = 900, steps = 11, total reward = 10,
# ep = 901, steps = 14, total reward = 7,
# ep = 902, steps = 12, total reward = 9,
# ep = 903, steps = 10, total reward = 11,
# ep = 904, steps = 14, total reward = 7,
# ep = 905, steps = 15, total reward = 6,
# ep = 906, steps = 23, total reward = -2,
# ep = 907, steps = 14, total reward = 7,
# ep = 908, steps = 12, total reward = 9,
# ep = 909, steps = 11, total reward = 10,
# ep = 910, steps = 14, total reward = 7,
# ep = 911, steps = 7, total reward = 14,
# ep = 912, steps = 11, total reward = 10,
# ep = 913, steps = 13, total reward = 8,
# ep = 914, steps = 15, total reward = 6,
# ep = 915, steps = 11, total reward = 10,
# ep = 916, steps = 11, total reward = 10,
# ep = 917, steps = 17, total reward = 4,
# ep = 918, steps = 10, total reward = 11,
# ep = 919, steps = 11, total reward = 10,
# ep = 920, steps = 12, total reward = 9,
# ep = 921, steps = 13, total reward = 8,
# ep = 922, steps = 12, total reward = 9,
# ep = 923, steps = 14, total reward = 7,
# ep = 924, steps = 13, total reward = 8,
# ep = 925, steps = 13, total reward = 8,
# ep = 926, steps = 18, total reward = 3,
# ep = 927, steps = 13, total reward = 8,
# ep = 928, steps = 14, total reward = 7,
# ep = 929, steps = 14, total reward = 7,
# ep = 930, steps = 11, total reward = 10,
# ep = 931, steps = 15, total reward = 6,
# ep = 932, steps = 9, total reward = 12,
# ep = 933, steps = 8, total reward = 13,
# ep = 934, steps = 11, total reward = 10,
# ep = 935, steps = 16, total reward = 5,
# ep = 936, steps = 13, total reward = 8,
# ep = 937, steps = 14, total reward = 7,
# ep = 938, steps = 15, total reward = -3,
# ep = 939, steps = 8, total reward = 13,
# ep = 940, steps = 14, total reward = 7,
# ep = 941, steps = 8, total reward = 13,
# ep = 942, steps = 15, total reward = 6,
# ep = 943, steps = 10, total reward = 11,
# ep = 944, steps = 10, total reward = 11,
# ep = 945, steps = 9, total reward = 12,
# ep = 946, steps = 16, total reward = 5,
# ep = 947, steps = 13, total reward = 8,
# ep = 948, steps = 15, total reward = 6,
# ep = 949, steps = 10, total reward = 11,
# ep = 950, steps = 17, total reward = 4,
# ep = 951, steps = 15, total reward = 6,
# ep = 952, steps = 13, total reward = -1,
# ep = 953, steps = 15, total reward = 6,
# ep = 954, steps = 6, total reward = 15,
# ep = 955, steps = 15, total reward = 6,
# ep = 956, steps = 14, total reward = -2,
# ep = 957, steps = 12, total reward = 9,
# ep = 958, steps = 14, total reward = 7,
# ep = 959, steps = 15, total reward = 6,
# ep = 960, steps = 13, total reward = 8,
# ep = 961, steps = 14, total reward = 7,
# ep = 962, steps = 16, total reward = 5,
# ep = 963, steps = 10, total reward = 11,
# ep = 964, steps = 17, total reward = 4,
# ep = 965, steps = 13, total reward = 8,
# ep = 966, steps = 13, total reward = 8,
# ep = 967, steps = 11, total reward = 10,
# ep = 968, steps = 14, total reward = 7,
# ep = 969, steps = 15, total reward = -3,
# ep = 970, steps = 16, total reward = 5,
# ep = 971, steps = 13, total reward = 8,
# ep = 972, steps = 11, total reward = 10,
# ep = 973, steps = 13, total reward = 8,
# ep = 974, steps = 12, total reward = 9,
# ep = 975, steps = 13, total reward = 8,
# ep = 976, steps = 13, total reward = 8,
# ep = 977, steps = 17, total reward = 4,
# ep = 978, steps = 11, total reward = 10,
# ep = 979, steps = 17, total reward = 4,
# ep = 980, steps = 14, total reward = 7,
# ep = 981, steps = 12, total reward = 9,
# ep = 982, steps = 16, total reward = 5,
# ep = 983, steps = 12, total reward = 9,
# ep = 984, steps = 15, total reward = 6,
# ep = 985, steps = 10, total reward = 11,
# ep = 986, steps = 16, total reward = 5,
# ep = 987, steps = 14, total reward = 7,
# ep = 988, steps = 11, total reward = 10,
# ep = 989, steps = 14, total reward = 7,
# ep = 990, steps = 16, total reward = 5,
# ep = 991, steps = 9, total reward = 12,
# ep = 992, steps = 16, total reward = 5,
# ep = 993, steps = 17, total reward = 4,
# ep = 994, steps = 12, total reward = 9,
# ep = 995, steps = 10, total reward = 11,
# ep = 996, steps = 13, total reward = 8,
# ep = 997, steps = 11, total reward = 10,
# ep = 998, steps = 14, total reward = 7,
# ep = 999, steps = 13, total reward = 8,

# %%
xy = seq_to_col_row(25,5)
xy
# Out:
# array([[5, 0]])

# %%
row_col_to_seq(np.array([[0,0]]),5)
# Out:
# array([0])

# %%
Qopt = {i:np.zeros((500//20,6-2)) for i in range(4)} #Q-values for each option

# %%
Qopt.keys()
# Out:
# dict_keys([0, 1, 2, 3])

# %%
Qopt[0].shape
# Out:
# (25, 4)
